# %% [markdown]
# Must use pytorch version 2.8.0
# https://pytorch.org/get-started/previous-versions/[link text](https://)

# %%
# install with this command, without this version for pytorch, profiling for decoder will fail
# !pip install torch==2.8.0 torchvision==0.23.0 torchaudio==2.8.0 --index-url https://download.pytorch.org/whl/cu129

# %%
import torch
print(torch.__version__)
# Out:
# 2.8.0+cu129

# %%
# !git clone https://gitlab.com/itsPronay/faster-whisper-benchmark.git
# Out:
# Cloning into 'faster-whisper-benchmark'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 23 (delta 1), reused 0 (delta 0), pack-reused 20 (from 1)
# Receiving objects: 100% (23/23), 8.63 KiB | 4.32 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
# !pip3 install qai-hub
# !qai-hub configure --api_token API_TOKEN
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 13.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 110.5 MB/s eta 0:00:00
# ...
# 2026-03-17 20:00:10.328 - INFO - Enabling verbose logging.
# qai-hub configuration saved to /root/.qai_hub/client.ini
# ==================== /root/.qai_hub/client.ini ====================
# [api]
# api_token = vqh9wt98ef7yptfydrf1tiuf6i5klo3q74gu52kv
# api_url = https://workbench.aihub.qualcomm.com
# web_url = https://workbench.aihub.qualcomm.com
# verbose = True

# %%
# !pip install wandb
import wandb
wandb.login()
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: itspronay (itspronay-southeast-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# !python /content/faster-whisper-benchmark/main.py
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: itspronay (itspronay-southeast-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ setting up run 5gna6n0d (0.2s)
# wandb: ⣽ setting up run 5gna6n0d (0.2s)
# wandb: ⣾ setting up run 5gna6n0d (0.2s)
# wandb: ⣷ setting up run 5gna6n0d (0.2s)
# wandb: ⣯ setting up run 5gna6n0d (0.2s)
# wandb: ⣟ setting up run 5gna6n0d (0.7s)
# wandb: ⡿ setting up run 5gna6n0d (0.7s)
# wandb: ⢿ setting up run 5gna6n0d (0.7s)
# wandb: ⣻ setting up run 5gna6n0d (0.7s)
# wandb: Tracking run with wandb version 0.25.1
# wandb: Run data is saved locally in /content/wandb/run-20260317_213138-5gna6n0d
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Model: openai/whisper-small, Device: Samsung Galaxy S24 (Family),
# ...
